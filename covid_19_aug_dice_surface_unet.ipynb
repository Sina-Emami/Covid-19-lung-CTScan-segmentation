# %% [markdown]
# # **Import data from kaggel**

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)

# %%
import os
os.environ['KAGGLE_USERNAME'] = "" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# !kaggle datasets download -d andrewmvd/covid19-ct-scans # api copied from kaggle

# %%
# !mkdir input

# %%
# %cd input
# Out:
# /content/input

# %%
# !mkdir covid19-ct-scans

# %%
# !unzip /content/covid19-ct-scans.zip -d /content/input/covid19-ct-scans

# %% [markdown]
# # **Import libraries**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib

import tensorflow as tf
import keras

#import os
import random

import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2 as cv
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, Concatenate, UpSampling2D, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from keras.losses import binary_crossentropy
from keras import backend as K

import tqdm
import pickle
import imgaug as ia
import imgaug.augmenters as iaa

# %% [markdown]
# # **load metadata**

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  ...                            lung_and_infection_mask
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...  ...  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...  ...  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...  ...  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...  ...  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...  ...  ../input/covid19-ct-scans/lung_and_infection_m...
#
# [5 rows x 4 columns]

# %% [markdown]
# # **Histogram Equalization**

# %%
img_size = 128
clahe = cv.createCLAHE(clipLimit=3.0)

def clahe_enhancer(img, clahe, axes):
    '''Contract Limited Adaptive Histogram Equalizer'''
    img = np.uint8(img*255)  
    clahe_img = clahe.apply(img)

    if len(axes) > 0 :    
        axes[0].imshow(img, cmap='bone')
        axes[0].set_title("Original CT scan")
        axes[0].set_xticks([]); axes[0].set_yticks([])

        axes[1].imshow(clahe_img, cmap='bone')
        axes[1].set_title("CLAHE Enhanced CT scan")
        axes[1].set_xticks([]); axes[1].set_yticks([])

        if len(axes) > 2 :
            axes[2].hist(img.flatten(), alpha=0.4, label='Original CT scan')
            axes[2].hist(clahe_img.flatten(), alpha=0.4, label="CLAHE Enhanced CT scan")
            plt.legend()
        
    return(clahe_img)

# %%
cts = nib.load(data.loc[0, 'ct_scan'])
slices = cts.shape[2]
print('Number of slices: ', slices)
    
arr = cts.get_fdata()
arr = np.rot90(np.array(arr))
arr = arr[:,:,range(80,200,20)]

#np.moveaxis
arr = np.reshape(np.rollaxis(arr, 2),(arr.shape[2],arr.shape[0],arr.shape[1], 1))

fig, axes = plt.subplots(3, 6, figsize=(21,10))    

for ii in range(arr.shape[0]):
    img = cv.resize(arr[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    xmax, xmin = img.max(), img.min()
    img = (img - xmin)/(xmax - xmin)
    clahe_img = clahe_enhancer(img, clahe, list(axes[:, ii]))
# Out:
# Number of slices:  301
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # **Crop image**

# %%
def get_contours(img):
    img = np.uint8(img*255)
    
    kernel = np.ones((3,3),np.float32)/9
    img = cv.filter2D(img, -1, kernel)
    
    ret, thresh = cv.threshold(img, 50, 255, cv.THRESH_BINARY)
    contours, hierarchy = cv.findContours(thresh, 2, 1)
    #Areas = [cv.contourArea(cc) for cc in contours]; print(Areas)
    
    size = get_size(img)
    contours = [cc for cc in contours if contourOK(cc, size)]
    return contours
    

def get_size(img):
    ih, iw = img.shape
    return iw * ih

def contourOK(cc, size):
    x, y, w, h = cv.boundingRect(cc)
    if ((w < 50 and h > 150) or (w > 150 and h < 50)) : 
        return False # too narrow or wide is bad
    area = cv.contourArea(cc)
    return area < (size * 0.5) and area > 200

def find_boundaries(img, contours):
    ih, iw = img.shape
    minx = iw
    miny = ih
    maxx = 0
    maxy = 0

    for cc in contours:
        x, y, w, h = cv.boundingRect(cc)
        if x < minx: minx = x
        if y < miny: miny = y
        if x + w > maxx: maxx = x + w
        if y + h > maxy: maxy = y + h

    return (minx, miny, maxx, maxy)

def crop_(img, boundaries):
    minx, miny, maxx, maxy = boundaries
    return img[miny:maxy, minx:maxx]
    
def crop_img(img, axes) :
    contours = get_contours(img)
    #plt.figure() # uncomment to troubleshoot
    #canvas = np.zeros_like(img)
    #cv.drawContours(canvas , contours, -1, (255, 255, 0), 1)
    #plt.imshow(canvas)
    bounds = find_boundaries(img, contours)
    cropped_img = crop_(img, bounds)

    if len(axes) > 0 :
        axes[0].imshow(img, cmap='bone')
        axes[0].set_title("Original CT scan")
        axes[0].set_xticks([]); axes[0].set_yticks([])
        
        axes[1].imshow(cropped_img, cmap='bone')
        axes[1].set_title("Cropped CT scan")
        axes[1].set_xticks([]); axes[1].set_yticks([])
        
    return cropped_img, bounds

# %%
cts = nib.load(data.loc[0, 'ct_scan'])
slices = cts.shape[2]
print('Number of slices: ', slices)
    
arr = cts.get_fdata()
arr = np.rot90(arr)
arr = arr[:,:,range(90,200,20)]

#np.moveaxis
arr = np.reshape(np.rollaxis(arr, 2),(arr.shape[2],arr.shape[0],arr.shape[1], 1))

fig, axes = plt.subplots(3, 6, figsize=(18,9))    

for ii in range(arr.shape[0]):
    img = cv.resize(arr[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    xmax, xmin = img.max(), img.min()
    img = (img - xmin)/(xmax - xmin)
    axes[0,ii].imshow(img, cmap='bone')
    axes[0,ii].set_title('Original CT')
    axes[0,ii].set_xticks([]); axes[0,ii].set_yticks([])
    
    clahe_img = clahe_enhancer(img, clahe, [])
    axes[1,ii].imshow(clahe_img, cmap='bone')
    axes[1,ii].set_title('Enhanced CT')
    axes[1,ii].set_xticks([]); axes[1,ii].set_yticks([])
    
    _, bounds = crop_img(img, [])
    cropped_img = crop_(clahe_img, bounds)
    axes[2,ii].imshow(cropped_img, cmap='bone')
    axes[2,ii].set_title('Enhanced & cropped')
    axes[2,ii].set_xticks([]); axes[2,ii].set_yticks([])
# Out:
# Number of slices:  301

# %%
cts = nib.load(data.loc[0, 'ct_scan'])
lungs = nib.load(data.loc[0, 'lung_mask'])
infec = nib.load(data.loc[0, 'infection_mask'])
slices = cts.shape[2]
    
arr_cts = cts.get_fdata()
arr_lungs = lungs.get_fdata()
arr_infec = infec.get_fdata()

arr_cts = np.rot90(arr_cts)
arr_lungs = np.rot90(arr_lungs)
arr_infec = np.rot90(arr_infec)

arr_cts = arr_cts[:, :, range(92,200,20)]
arr_lungs = arr_lungs[:, :, range(92,200,20)]
arr_infec = arr_infec[:, :, range(92,200,20)]

#np.moveaxis
arr_cts = np.reshape(np.rollaxis(arr_cts, 2), (arr_cts.shape[2],arr_cts.shape[0],arr_cts.shape[1], 1))
arr_lungs = np.reshape(np.rollaxis(arr_lungs, 2), (arr_lungs.shape[2],arr_lungs.shape[0],arr_lungs.shape[1], 1))
arr_infec = np.reshape(np.rollaxis(arr_infec, 2), (arr_infec.shape[2],arr_infec.shape[0],arr_infec.shape[1], 1))

fig, axes = plt.subplots(3, 6, figsize=(18,6))    

for ii in range(arr_cts.shape[0]):
    img_ct = cv.resize(arr_cts[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    img_lungs = cv.resize(arr_lungs[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    img_infec = cv.resize(arr_infec[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)

    xmax, xmin = img_lungs.max(), img_lungs.min()
    img_lungs = (img_lungs - xmin)/(xmax - xmin)
    cropped_lungs, bounds = crop_img(img_lungs, [])
    
    xmax, xmin = img_ct.max(), img_ct.min()
    img_ct = (img_ct - xmin)/(xmax - xmin)
    clahe_ct = clahe_enhancer(img_ct, clahe, [])
    cropped_ct = crop_(clahe_ct, bounds)
    cropped_infec = crop_(img_infec, bounds)
    
    axes[0,ii].imshow(cropped_ct, cmap='bone')
    axes[0,ii].set_title("CT scan")
    axes[0,ii].set_xticks([]); axes[0,ii].set_yticks([])
    
    axes[1,ii].imshow(cropped_ct, cmap='bone')
    axes[1,ii].imshow(cropped_lungs, alpha = 0.5, cmap='Reds')
    axes[1,ii].set_title("Lungs mask")
    axes[1,ii].set_xticks([]); axes[1,ii].set_yticks([])

    axes[2,ii].imshow(cropped_ct, cmap='bone')
    axes[2,ii].imshow(cropped_infec, alpha = 0.5, cmap = 'nipy_spectral')
    axes[2,ii].set_title("Infection mask")
    axes[2,ii].set_xticks([]); axes[2,ii].set_yticks([])

# %% [markdown]
# # **Load all the data**

# %%
cts_all = []
#lungs_all = []
infects_all = []
max_w, max_h = 0, 0 #max width and height

for fnum in tqdm.tqdm(range(20)) : #range(metadata.shape[0])) :
    cts = nib.load(data.loc[fnum, 'ct_scan'])
    lungs = nib.load(data.loc[fnum, 'lung_mask'])
    infec = nib.load(data.loc[fnum, 'infection_mask'])
    
    slices = cts.shape[2]

    arr_cts = cts.get_fdata()
    arr_lungs = lungs.get_fdata()
    arr_infec = infec.get_fdata()

    arr_cts = np.rot90(arr_cts)
    arr_lungs = np.rot90(np.array(arr_lungs))
    arr_infec = np.rot90(arr_infec)

    arr_cts = arr_cts[:, :, round(slices*0.2):round(slices*0.8)]
    arr_lungs = arr_lungs[:, :, round(slices*0.2):round(slices*0.8)]
    arr_infec = arr_infec[:, :, round(slices*0.2):round(slices*0.8)]

    arr_cts = np.reshape(np.rollaxis(arr_cts, 2), (arr_cts.shape[2],arr_cts.shape[0],arr_cts.shape[1], 1))
    arr_lungs = np.reshape(np.rollaxis(arr_lungs, 2), (arr_lungs.shape[2],arr_lungs.shape[0],arr_lungs.shape[1], 1))
    arr_infec = np.reshape(np.rollaxis(arr_infec, 2), (arr_infec.shape[2],arr_infec.shape[0],arr_infec.shape[1], 1))
    
    for ii in range(arr_cts.shape[0]):
    
        img_lungs = cv.resize(arr_lungs[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
        xmax, xmin = img_lungs.max(), img_lungs.min()
        img_lungs = (img_lungs - xmin)/(xmax - xmin)
        cropped_lungs, bounds = crop_img(img_lungs, [])
        #lungs_all.append(cropped_lungs)
        

        h, w = cropped_img.shape
        max_h, max_w = max(max_h, h), max(max_w, w)

        img_ct = cv.resize(arr_cts[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
        xmax, xmin = img_ct.max(), img_ct.min()
        img_ct = (img_ct - xmin)/(xmax - xmin)
        clahe_ct = clahe_enhancer(img_ct, clahe, [])
        cropped_ct = crop_(clahe_ct, bounds)
        cts_all.append(cropped_ct)

        img_infec = cv.resize(arr_infec[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
        cropped_infec = crop_(img_infec, bounds)
        infects_all.append(cropped_infec)
# Out:
#  45%|████▌     | 9/20 [01:19<01:57, 10.66s/it]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# 100%|██████████| 20/20 [02:26<00:00,  7.32s/it]

# %%
print("total number of ct slices:",len(cts_all))
# Out:
# total number of ct slices: 2112

# %% [markdown]
# **Resize and reshape**

# %%
num_pix = 128
del_lst = []
for ii in tqdm.tqdm(range(len(cts_all))) :
    try :
        cts_all[ii] = cv.resize(cts_all[ii], dsize=(num_pix, num_pix), interpolation=cv.INTER_AREA)
        cts_all[ii] = np.reshape(cts_all[ii], (num_pix, num_pix, 1))

        #lungs_all[ii] = cv.resize(lungs_all[ii], dsize=(num_pix, num_pix), interpolation=cv.INTER_AREA)
        #lungs_all[ii] = np.reshape(lungs_all[ii], (num_pix, num_pix, 1))

        infects_all[ii] = cv.resize(infects_all[ii], dsize=(num_pix, num_pix), interpolation=cv.INTER_AREA)
        infects_all[ii] = np.reshape(infects_all[ii], (num_pix, num_pix, 1))
    except :
        del_lst.append(ii)
        
for idx in del_lst[::-1] :
    del cts_all[idx]
    #del lungs_all[idx]
    del infects_all[idx]
# Out:
# 100%|██████████| 2112/2112 [00:00<00:00, 11687.83it/s]

# %%
print("total number of slices that must be deleted: ",len(del_lst))
# Out:
# total number of slices that must be deleted:  45

# %%
fig, axes = plt.subplots(1, 2, figsize=(6,3))

slice_id = 1050
axes[0].imshow(cts_all[slice_id][:, :, 0], cmap='bone')
axes[0].set_title("Enhanced & Cropped CT")

#axes[1].imshow(lungs_all[slice_id][:, :, 0], cmap='Greens')
#axes[1].set_title("Lungs")

axes[1].imshow(cts_all[slice_id][:, :, 0], cmap='bone')
axes[1].imshow(infects_all[slice_id][:, :, 0], alpha = 0.5, cmap = 'nipy_spectral')
axes[1].set_title("Infection");

# %% [markdown]
# # **saving the preprocessed data**

# %%
with open('preprocessed_cts.cp', 'wb') as myfile:
    pickle.dump({'cts_all': cts_all, 'infects_all': infects_all}, myfile)
    #print(cts_all)

# %%
# %cp "/content/input/preprocessed_cts.cp" "/content/drive/MyDrive/Colab Notebooks/Covid-19 U-Net/just dice 512*512/"

# %%
infect_bool = np.ones((1, len(infects_all)))
for ii in range(len(infects_all)):
    if np.unique(infects_all[ii]).size == 1:
        infect_bool[0, ii] = 0
        
print("Number of CTs with no infection: %d" %(len(infects_all)-infect_bool.sum()))
# Out:
# Number of CTs with no infection: 474

# %% [markdown]
# # **Data augmentation**

# %%
ia.seed(1)

seq = iaa.Sequential([
    #iaa.Fliplr(0.5), # horizontal flips
    #iaa.Flipud(0.5), # vertical flips
    
    # Apply affine transformations to each image.
    # Scale/zoom them, translate/move them, rotate them and shear them.
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)}, # scale images
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-15, 15),
        shear=(-15, 15)
    )
], random_order=True) # apply augmenters in random order

# %%
num_augs = round(len(cts_all)/2.)
rand_idx = np.random.randint(0, len(cts_all), size=num_augs)

sample_cts = [cts_all[ii] for ii in rand_idx]
#sample_lungs = [lungs_all[ii] for ii in rand_idx]
sample_infects = [infects_all[ii] for ii in rand_idx]

# %%
seq_det = seq.to_deterministic()
cts_aug = seq_det.augment_images(sample_cts)
#lungs_aug = seq_det.augment_images(sample_lungs)
infects_aug = seq_det.augment_images(sample_infects)

# %%
fig, axes = plt.subplots(2, 5, figsize=(15,9))

for ii in range(5) :
    axes[0, ii].imshow(cts_aug[ii*10+50][:, :, 0], cmap='bone')
    axes[0, ii].set_title("Enhanced & Cropped CT")

    #axes[1, ii].imshow(lungs_aug[ii*10+50][:, :, 0], cmap='Greens')
    #axes[1, ii].set_title("Lungs")

    axes[1, ii].imshow(cts_aug[ii*10+50][:, :, 0], cmap='bone')
    axes[1, ii].imshow(infects_aug[ii*10+50][:, :, 0], alpha = 0.5, cmap = 'nipy_spectral')
    axes[1, ii].set_title("Infection")

# %% [markdown]
# **Pool augmented data and convert it**

# %%
cts_all = tf.convert_to_tensor(cts_all)
cts_aug = tf.convert_to_tensor(cts_aug)
#lungs_all = tf.convert_to_tensor(lungs_all)
#lungs_aug = tf.convert_to_tensor(lungs_aug)
infects_all = tf.convert_to_tensor(infects_all)
infects_aug = tf.convert_to_tensor(infects_aug)

cts = tf.concat([cts_all, cts_aug], axis=0)
#lungs = tf.concat([lungs_all, lungs_aug], axis=0)
infects = tf.concat([infects_all, infects_aug], axis=0)

# %%
indices = tf.range(start=0, limit=cts.shape[0], dtype=tf.int32)
shuffled_indices = tf.random.shuffle(indices)
                       
cts = tf.gather(cts, shuffled_indices)
#lungs = tf.gather(lungs, shuffled_indices)
infects = tf.gather(infects, shuffled_indices)

print("ct shape: ", cts.shape," and the infects mask shape: ", infects.shape)
# Out:
# ct shape:  (3101, 128, 128, 1)  and the infects mask shape:  (3101, 128, 128, 1)

# %% [markdown]
# # **Saving the augmented data**

# %%
with open('augmented_cts.cp', 'wb') as myfile:
    pickle.dump({'cts': cts, 'infects': infects}, myfile)

# %%
# %cp "/content/input/augmented_cts.cp" "/content/drive/MyDrive/Colab Notebooks/Covid-19 U-Net/just dice 512*512/"

# %% [markdown]
# **plot to test some data**

# %%
def plot_cts_infects(ct, infect, axes) :

    axes[0].imshow(ct[:,:,0], cmap='bone')
    axes[0].set_title('CT image')

    axes[1].imshow(ct[:,:,0], cmap='bone')
    axes[1].imshow(infect[:,:,0], alpha=0.5, cmap='nipy_spectral')
    axes[1].set_title('Infection')

# %%
fig, axes = plt.subplots(2, 5, figsize=(15,6))

for ii, idx in enumerate(range(150, 350, 40)) :
    plot_cts_infects(cts[idx], infects[idx], list(axes[:,ii]))

# %% [markdown]
# # **split data into trainset, testset, validationset**

# %%
train_size = int(0.8*cts.shape[0])
test_size = int(0.1*cts.shape[0])

Xct_train, yinfect_train = (cts[:train_size]/255, infects[:train_size])

Xct_valid, yinfect_valid = (cts[train_size:train_size+test_size]/255, infects[train_size:train_size+test_size])

Xct_test, yinfect_test = (cts[train_size+test_size:]/255, infects[train_size+test_size:])

print("train set size: ", Xct_train.shape, yinfect_train.shape)
print("validation set size: ", Xct_valid.shape, yinfect_valid.shape)
print("test set size: ", Xct_test.shape, yinfect_test.shape)
# Out:
# train set size:  (2480, 128, 128, 1) (2480, 128, 128, 1)
# validation set size:  (310, 128, 128, 1) (310, 128, 128, 1)
# test set size:  (311, 128, 128, 1) (311, 128, 128, 1)

# %% [markdown]
# # **Define loss function and metrics**

# %% [markdown]
# **weighted_dice_loss:**

# %%
def dice_loss(y_true, y_pred):
    smooth = 1.0
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f**2) + K.sum(y_pred_f**2) + smooth)
    return 1.0 - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

#def bce_logdice_loss(y_true, y_pred):
#    return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

def weighted_bce_loss(y_true, y_pred, weight):
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    loss = weight * (logit_y_pred * (1. - y_true) + K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)

'''
def weighted_dice_loss(y_true, y_pred, weight):
    smooth = 1.
    w, m1, m2 = weight, y_true, y_pred
    intersection = (m1 * m2)
    score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
    loss = 1. - K.sum(score)
    return loss
'''

def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd
    averaged_mask = K.pool2d(y_true, pool_size=(50, 50), strides=(1, 1), padding='same', pool_mode='avg')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight = 5. * K.exp(-5. * K.abs(averaged_mask - 0.5))
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = weighted_bce_loss(y_true, y_pred, weight) + dice_loss(y_true, y_pred)
    return loss

# %% [markdown]
# **surfaceloss:**

# %%
from scipy.ndimage import distance_transform_edt as distance


def calc_dist_map(seg):
    res = np.zeros_like(seg)
    posmask = seg.astype(np.bool)

    if posmask.any():
        negmask = ~posmask
        res = distance(negmask) * negmask - (distance(posmask) - 1) * posmask

    return res


def calc_dist_map_batch(y_true):
    y_true_numpy = y_true
    return np.array([calc_dist_map(y)
                     for y in y_true_numpy]).astype(np.float32)


def surface_loss_keras(y_true, y_pred):
    y_true_dist_map = tf.compat.v1.py_func(func=calc_dist_map_batch,
                                     inp=[y_true],
                                     Tout=tf.float32)
    multipled = y_pred * y_true_dist_map
    return K.mean(multipled)

# %% [markdown]
# sum them up:

# %%
def gl_sl_wrapper(alpha):
    def gl_sl(y_true, y_pred):
        return alpha* weighted_bce_dice_loss(y_true, y_pred) +  (1-alpha)* surface_loss_keras(y_true, y_pred)
    return gl_sl

# %%
from keras.callbacks import ModelCheckpoint, Callback

class AlphaScheduler(Callback):
  def init(self, alpha, update_fn):
    self.alpha = alpha
    self.update_fn = update_fn
  def on_epoch_end(self, epoch, logs=None):
    updated_alpha = self.update_fn(K.get_value(self.alpha))

alpha = K.variable(1, dtype='float32')

def update_alpha(value):
  return np.clip(value - 0.01, 0.01, 1)

# %% [markdown]
# **Other Metrics:**

# %%
def dice_coef(y_true, y_pred, smooth = 1.0):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

# %%
def iou(y_true, y_pred, smooth = 0.0001):
  intersection = K.sum(y_true * y_pred)
  sum_ = K.sum(y_true + y_pred)
  jac = (intersection + smooth) / (sum_ - intersection + smooth)
  return jac

# %% [markdown]
# # **Define Unet**

# %%
def unet(input_size=(128,128,1), dfilters=64, ufilters=64, dropout_rate=0.5):
    inputs = Input(input_size)
    
    conv1 = Conv2D(dfilters,kernel_size=(3,3),strides=(1,1),padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(dfilters,kernel_size=(3,3),strides=(1,1),padding='same')(bn1)
    bn1 = Activation('relu')(conv1)
    pool1=MaxPooling2D((2,2))(bn1)
    ################################################################################
    conv2 = Conv2D(dfilters*2,kernel_size=(3,3),strides=(1,1),padding='same')(pool1)
    bn2 = BatchNormalization()(conv2)
    bn2 = Activation('relu')(bn2)
    conv2 = Conv2D(dfilters*2,kernel_size=(3,3),strides=(1,1),padding='same')(bn2)
    bn2 = BatchNormalization()(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D((2,2))(bn2)
    ################################################################################
    conv3 = Conv2D(dfilters*4,kernel_size=(3,3),strides=(1,1),padding='same')(pool2)
    bn3 = BatchNormalization()(conv3)
    bn3 = Activation('relu')(bn3)
    conv3 = Conv2D(dfilters*4,kernel_size=(3,3),strides=(1,1),padding='same')(bn3)
    bn3 = BatchNormalization()(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D((2,2))(bn3)
    ################################################################################
    conv4 = Conv2D(dfilters*8,kernel_size=(3,3),strides=(1,1),padding='same')(pool3)
    bn4 = BatchNormalization()(conv4)
    bn4 = Activation('relu')(bn4)
    conv4 = Conv2D(dfilters*8,kernel_size=(3,3),strides=(1,1),padding='same')(bn4)
    bn4 = BatchNormalization()(conv4)
    bn4 = Activation('relu')(bn4)
    bn4 = Dropout(dropout_rate)(bn4)
    pool4 = MaxPooling2D((2,2))(bn4)
    ################################################################################
    conv5 = Conv2D(dfilters*16,kernel_size=(3,3),strides=(1,1),padding='same')(pool4)
    bn5 = BatchNormalization()(conv5)
    bn5 = Activation('relu')(bn5)
    conv5 = Conv2D(dfilters*16,kernel_size=(3,3),strides=(1,1),padding='same')(bn5)
    bn5 = BatchNormalization()(conv5)
    bn5 = Activation('relu')(bn5)
    bn5 = Dropout(dropout_rate)(bn5)
    ################################################################################
    up6 = UpSampling2D((2,2))(bn5)
    conv6 = Conv2D(dfilters*8,kernel_size=(3,3),strides=(1,1),padding='same')(up6)
    bn6 = BatchNormalization()(conv6)
    bn6 = Activation('relu')(bn6)
    
    atb_g6 = Conv2D(ufilters*8,kernel_size=(1,1),strides=(1,1),padding='valid')(bn6)
    atb_g6 = BatchNormalization()(atb_g6)
    atb_x6 = Conv2D(ufilters*8,kernel_size=(1,1),strides=(1,1),padding='valid')(bn4)
    atb_x6 = BatchNormalization()(atb_x6)
    psi6 = Add()([atb_g6,atb_x6])
    psi6 = Activation('relu')(psi6)
    psi6 = Conv2D(1,kernel_size=(1,1),strides=(1,1),padding='valid')(psi6)
    psi6 = BatchNormalization()(psi6)
    conv6 = Activation('sigmoid')(psi6)
    
    up6 = Concatenate()([up6,conv6])
    
    conv6 = Conv2D(ufilters*8,kernel_size=(3,3),strides=(1,1),padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(ufilters*8,kernel_size=(3,3),strides=(1,1),padding='same')(bn6)
    bn6 = Activation('relu')(conv6)
    ################################################################################
    up7 = UpSampling2D((2,2))(bn6)
    conv7 = Conv2D(dfilters*4,kernel_size=(3,3),strides=(1,1),padding='same')(up7)
    bn7 = BatchNormalization()(conv7)
    bn7 = Activation('relu')(bn7)
    
    atb_g7 = Conv2D(ufilters*4,kernel_size=(1,1),strides=(1,1),padding='valid')(bn7)
    atb_g7 = BatchNormalization()(atb_g7)
    atb_x7 = Conv2D(ufilters*4,kernel_size=(1,1),strides=(1,1),padding='valid')(bn3)
    atb_x7 = BatchNormalization()(atb_x7)
    psi7 = Add()([atb_g7,atb_x7])
    psi7 = Activation('relu')(psi7)
    psi7 = Conv2D(1,kernel_size=(1,1),strides=(1,1),padding='valid')(psi7)
    psi7 = BatchNormalization()(psi7)
    conv7 = Activation('sigmoid')(psi7)
    
    up7 = Concatenate()([up7,conv7])
    
    conv7 = Conv2D(ufilters*4,kernel_size=(3,3),strides=(1,1),padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(ufilters*4,kernel_size=(3,3),strides=(1,1),padding='same')(bn7)
    bn7 = Activation('relu')(conv7)
    ################################################################################
    up8 = UpSampling2D((2,2))(bn7)
    conv8 = Conv2D(dfilters*2,kernel_size=(3,3),strides=(1,1),padding='same')(up8)
    bn8 = BatchNormalization()(conv8)
    bn8 = Activation('relu')(bn8)
    
    atb_g8 = Conv2D(ufilters*2,kernel_size=(1,1),strides=(1,1),padding='valid')(bn8)
    atb_g8 = BatchNormalization()(atb_g8)
    atb_x8 = Conv2D(ufilters*2,kernel_size=(1,1),strides=(1,1),padding='valid')(bn2)
    atb_x8 = BatchNormalization()(atb_x8)
    psi8 = Add()([atb_g8,atb_x8])
    psi8 = Activation('relu')(psi8)
    psi8 = Conv2D(1,kernel_size=(1,1),strides=(1,1),padding='valid')(psi8)
    psi8 = BatchNormalization()(psi8)
    conv8 = Activation('sigmoid')(psi8)
    
    up8 = Concatenate()([up8,conv8])
    
    conv8 = Conv2D(ufilters*2,kernel_size=(3,3),strides=(1,1),padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(ufilters*2,kernel_size=(3,3),strides=(1,1),padding='same')(bn8)
    bn8 = Activation('relu')(conv8)
    ################################################################################
    up9 = UpSampling2D((2,2))(bn8)
    conv9 = Conv2D(dfilters,kernel_size=(3,3),strides=(1,1),padding='same')(up9)
    bn9 = BatchNormalization()(conv9)
    bn9 = Activation('relu')(bn9)
    
    atb_g9 = Conv2D(ufilters,kernel_size=(1,1),strides=(1,1),padding='valid')(bn9)
    atb_g9 = BatchNormalization()(atb_g9)
    atb_x9 = Conv2D(ufilters,kernel_size=(1,1),strides=(1,1),padding='valid')(bn1)
    atb_x9 = BatchNormalization()(atb_x9)
    psi9 = Add()([atb_g9,atb_x9])
    psi9 = Activation('relu')(psi9)
    psi9 = Conv2D(1,kernel_size=(1,1),strides=(1,1),padding='valid')(psi9)
    psi9 = BatchNormalization()(psi9)
    conv9 = Activation('sigmoid')(psi9)
    
    up9 = Concatenate()([up9,conv9])
    
    conv9 = Conv2D(ufilters,kernel_size=(3,3),strides=(1,1),padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(ufilters,kernel_size=(3,3),strides=(1,1),padding='same')(bn9)
    bn9 = Activation('relu')(conv9)
    ################################################################################
    outputs = Conv2D(1,kernel_size=(1,1),strides=(1,1),activation='sigmoid')(bn9)
    
    model = Model(inputs=inputs,outputs=outputs)
    
    return model

# %% [markdown]
# # **Compile and fit the model**

# %%
weight_path="{}_weights.augmenteddicesurface.hdf5".format('model')
checkpoint = ModelCheckpoint(weight_path, monitor='val_dice_coef', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)

# %%
BATCH_SIZE = 32
learning_rate = 1e-4
EPOCHS = 50

# %%
model = unet(input_size=(img_size, img_size, 1))

decay_rate = learning_rate / EPOCHS
opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=decay_rate, amsgrad=False)

model.compile(optimizer=opt, loss=gl_sl_wrapper(alpha), metrics=[dice_coef, iou])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 128)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 128)  147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 128)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 512)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 512)  2359808     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 512)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)    0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 1024)   4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 1024)   4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 1024)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 1024)   9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 1024)   4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 1024)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 1024)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 1024) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 512)  4719104     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 512)  262656      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 512)  262656      dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 512)  0           batch_normalization_9[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 512)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 1)    513         activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 1)    4           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 1)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 1025) 0           up_sampling2d[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 512)  4723712     concatenate[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 512)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 512)  2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 512)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 512)  0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 256)  1179904     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 256)  65792       activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 256)  65792       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 256)  1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 1)    257         activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 1)    4           conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 1)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 513)  0           up_sampling2d_1[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 256)  1182208     concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 256)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 256)  590080      activation_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 256)  0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 256)  0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 128)  295040      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 128)  16512       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 128)  16512       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 128)  512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 128)  0           batch_normalization_17[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 1)    129         activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 1)    4           conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 1)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 257)  0           up_sampling2d_2[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 128)  296192      concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 128)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 128)  147584      activation_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 64, 128)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 128 0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 128, 64) 73792       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 128, 128, 64) 256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 128, 128, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 128, 128, 64) 4160        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 128, 128, 64) 4160        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 128, 128, 64) 256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 64) 256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 64) 0           batch_normalization_21[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 128, 128, 64) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 128, 128, 1)  65          activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 1)  4           conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 128, 128, 1)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 129 0           up_sampling2d_3[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 128, 128, 64) 74368       concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 128, 128, 64) 0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 64) 36928       activation_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 128, 128, 64) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 1)  65          activation_29[0][0]
# ==================================================================================================
# Total params: 35,246,933
# Trainable params: 35,233,485
# Non-trainable params: 13,448
# __________________________________________________________________________________________________

# %%
#callbacks = [ModelCheckpoint('unet_brain_mri_seg.hdf5', verbose=1, save_best_only=True)]

history = model.fit(Xct_train, yinfect_train, epochs=EPOCHS,
                    validation_data = (Xct_valid, yinfect_valid),
                    callbacks=[checkpoint])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From <ipython-input-37-9f4020fc8923>:22: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# 78/78 [==============================] - 71s 709ms/step - loss: 0.9836 - dice_coef: 0.1299 - iou: 0.1096 - val_loss: 1.4108 - val_dice_coef: 0.0325 - val_iou: 0.0220
#
# Epoch 00001: val_dice_coef improved from -inf to 0.03255, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 2/50
# 78/78 [==============================] - 49s 635ms/step - loss: 0.4233 - dice_coef: 0.3426 - iou: 0.3692 - val_loss: 2.5957 - val_dice_coef: 0.0535 - val_iou: 1.4078e-04
#
# Epoch 00002: val_dice_coef improved from 0.03255 to 0.05351, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 3/50
# 78/78 [==============================] - 50s 642ms/step - loss: 0.3187 - dice_coef: 0.4158 - iou: 0.4473 - val_loss: 2.8504 - val_dice_coef: 0.0816 - val_iou: 8.4435e-05
#
# Epoch 00003: val_dice_coef improved from 0.05351 to 0.08162, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 4/50
# 78/78 [==============================] - 51s 648ms/step - loss: 0.2820 - dice_coef: 0.4457 - iou: 0.4796 - val_loss: 2.9320 - val_dice_coef: 0.1172 - val_iou: 3.7372e-05
#
# Epoch 00004: val_dice_coef improved from 0.08162 to 0.11725, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 5/50
# 78/78 [==============================] - 50s 648ms/step - loss: 0.2188 - dice_coef: 0.4897 - iou: 0.5418 - val_loss: 2.5738 - val_dice_coef: 0.0478 - val_iou: 7.6344e-04
#
# Epoch 00005: val_dice_coef did not improve from 0.11725
# Epoch 6/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.1954 - dice_coef: 0.5159 - iou: 0.5723 - val_loss: 2.5273 - val_dice_coef: 0.1039 - val_iou: 7.1017e-04
#
# Epoch 00006: val_dice_coef did not improve from 0.11725
# Epoch 7/50
# 78/78 [==============================] - 50s 640ms/step - loss: 0.1843 - dice_coef: 0.5277 - iou: 0.5870 - val_loss: 2.1480 - val_dice_coef: 0.1195 - val_iou: 0.0186
#
# Epoch 00007: val_dice_coef improved from 0.11725 to 0.11947, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 8/50
# 78/78 [==============================] - 50s 644ms/step - loss: 0.1719 - dice_coef: 0.5443 - iou: 0.5993 - val_loss: 0.4570 - val_dice_coef: 0.4128 - val_iou: 0.4340
#
# Epoch 00008: val_dice_coef improved from 0.11947 to 0.41282, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 9/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.1661 - dice_coef: 0.5441 - iou: 0.6179 - val_loss: 0.2578 - val_dice_coef: 0.4545 - val_iou: 0.5204
#
# Epoch 00009: val_dice_coef improved from 0.41282 to 0.45450, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 10/50
# 78/78 [==============================] - 50s 644ms/step - loss: 0.1486 - dice_coef: 0.5653 - iou: 0.6382 - val_loss: 0.1938 - val_dice_coef: 0.4968 - val_iou: 0.5761
#
# Epoch 00010: val_dice_coef improved from 0.45450 to 0.49681, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 11/50
# 78/78 [==============================] - 50s 642ms/step - loss: 0.1435 - dice_coef: 0.5636 - iou: 0.6362 - val_loss: 0.1753 - val_dice_coef: 0.5212 - val_iou: 0.5979
#
# Epoch 00011: val_dice_coef improved from 0.49681 to 0.52117, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 12/50
# 78/78 [==============================] - 50s 648ms/step - loss: 0.1329 - dice_coef: 0.5902 - iou: 0.6614 - val_loss: 0.1819 - val_dice_coef: 0.5073 - val_iou: 0.5836
#
# Epoch 00012: val_dice_coef did not improve from 0.52117
# Epoch 13/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.1305 - dice_coef: 0.5915 - iou: 0.6633 - val_loss: 0.1804 - val_dice_coef: 0.5318 - val_iou: 0.6076
#
# Epoch 00013: val_dice_coef improved from 0.52117 to 0.53184, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 14/50
# 78/78 [==============================] - 50s 644ms/step - loss: 0.1303 - dice_coef: 0.5869 - iou: 0.6622 - val_loss: 0.1651 - val_dice_coef: 0.5174 - val_iou: 0.6071
#
# Epoch 00014: val_dice_coef did not improve from 0.53184
# Epoch 15/50
# 78/78 [==============================] - 50s 639ms/step - loss: 0.1274 - dice_coef: 0.5887 - iou: 0.6655 - val_loss: 0.1995 - val_dice_coef: 0.4904 - val_iou: 0.5613
#
# Epoch 00015: val_dice_coef did not improve from 0.53184
# Epoch 16/50
# 78/78 [==============================] - 50s 641ms/step - loss: 0.1242 - dice_coef: 0.6048 - iou: 0.6677 - val_loss: 0.1791 - val_dice_coef: 0.5145 - val_iou: 0.5890
#
# Epoch 00016: val_dice_coef did not improve from 0.53184
# Epoch 17/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.1163 - dice_coef: 0.6229 - iou: 0.6852 - val_loss: 0.1689 - val_dice_coef: 0.5215 - val_iou: 0.5918
#
# Epoch 00017: val_dice_coef did not improve from 0.53184
# Epoch 18/50
# 78/78 [==============================] - 50s 641ms/step - loss: 0.1199 - dice_coef: 0.6162 - iou: 0.6851 - val_loss: 0.1876 - val_dice_coef: 0.5230 - val_iou: 0.5991
#
# Epoch 00018: val_dice_coef did not improve from 0.53184
# Epoch 19/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.1156 - dice_coef: 0.6176 - iou: 0.6847 - val_loss: 0.1771 - val_dice_coef: 0.5216 - val_iou: 0.6005
#
# Epoch 00019: val_dice_coef did not improve from 0.53184
# Epoch 20/50
# 78/78 [==============================] - 51s 648ms/step - loss: 0.1070 - dice_coef: 0.6380 - iou: 0.6941 - val_loss: 0.1668 - val_dice_coef: 0.5483 - val_iou: 0.6216
#
# Epoch 00020: val_dice_coef improved from 0.53184 to 0.54826, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 21/50
# 78/78 [==============================] - 50s 644ms/step - loss: 0.1084 - dice_coef: 0.6228 - iou: 0.6969 - val_loss: 0.1936 - val_dice_coef: 0.5231 - val_iou: 0.5935
#
# Epoch 00021: val_dice_coef did not improve from 0.54826
# Epoch 22/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.1041 - dice_coef: 0.6520 - iou: 0.7050 - val_loss: 0.1533 - val_dice_coef: 0.5538 - val_iou: 0.6323
#
# Epoch 00022: val_dice_coef improved from 0.54826 to 0.55379, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 23/50
# 78/78 [==============================] - 50s 644ms/step - loss: 0.1095 - dice_coef: 0.6367 - iou: 0.6923 - val_loss: 0.1639 - val_dice_coef: 0.5566 - val_iou: 0.6258
#
# Epoch 00023: val_dice_coef improved from 0.55379 to 0.55659, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 24/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.1007 - dice_coef: 0.6494 - iou: 0.7011 - val_loss: 0.1659 - val_dice_coef: 0.5499 - val_iou: 0.6317
#
# Epoch 00024: val_dice_coef did not improve from 0.55659
# Epoch 25/50
# 78/78 [==============================] - 50s 640ms/step - loss: 0.1016 - dice_coef: 0.6497 - iou: 0.7099 - val_loss: 0.1586 - val_dice_coef: 0.5836 - val_iou: 0.6445
#
# Epoch 00025: val_dice_coef improved from 0.55659 to 0.58365, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 26/50
# 78/78 [==============================] - 50s 638ms/step - loss: 0.0965 - dice_coef: 0.6573 - iou: 0.7101 - val_loss: 0.1723 - val_dice_coef: 0.5546 - val_iou: 0.6273
#
# Epoch 00026: val_dice_coef did not improve from 0.58365
# Epoch 27/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.0976 - dice_coef: 0.6573 - iou: 0.7108 - val_loss: 0.2366 - val_dice_coef: 0.4955 - val_iou: 0.5567
#
# Epoch 00027: val_dice_coef did not improve from 0.58365
# Epoch 28/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0940 - dice_coef: 0.6750 - iou: 0.7213 - val_loss: 0.1541 - val_dice_coef: 0.5612 - val_iou: 0.6345
#
# Epoch 00028: val_dice_coef did not improve from 0.58365
# Epoch 29/50
# 78/78 [==============================] - 50s 641ms/step - loss: 0.0922 - dice_coef: 0.6795 - iou: 0.7202 - val_loss: 0.1598 - val_dice_coef: 0.6119 - val_iou: 0.6478
#
# Epoch 00029: val_dice_coef improved from 0.58365 to 0.61188, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 30/50
# 78/78 [==============================] - 51s 654ms/step - loss: 0.0912 - dice_coef: 0.6707 - iou: 0.7200 - val_loss: 0.1651 - val_dice_coef: 0.5707 - val_iou: 0.6461
#
# Epoch 00030: val_dice_coef did not improve from 0.61188
# Epoch 31/50
# 78/78 [==============================] - 51s 653ms/step - loss: 0.0878 - dice_coef: 0.6832 - iou: 0.7208 - val_loss: 0.1474 - val_dice_coef: 0.6266 - val_iou: 0.6625
#
# Epoch 00031: val_dice_coef improved from 0.61188 to 0.62659, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 32/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0875 - dice_coef: 0.6810 - iou: 0.7258 - val_loss: 0.1671 - val_dice_coef: 0.5474 - val_iou: 0.6251
#
# Epoch 00032: val_dice_coef did not improve from 0.62659
# Epoch 33/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0875 - dice_coef: 0.6958 - iou: 0.7287 - val_loss: 0.1619 - val_dice_coef: 0.5853 - val_iou: 0.6442
#
# Epoch 00033: val_dice_coef did not improve from 0.62659
# Epoch 34/50
# 78/78 [==============================] - 50s 640ms/step - loss: 0.0846 - dice_coef: 0.6976 - iou: 0.7285 - val_loss: 0.1545 - val_dice_coef: 0.6421 - val_iou: 0.6592
#
# Epoch 00034: val_dice_coef improved from 0.62659 to 0.64214, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 35/50
# 78/78 [==============================] - 50s 644ms/step - loss: 0.0837 - dice_coef: 0.7115 - iou: 0.7340 - val_loss: 0.1521 - val_dice_coef: 0.6182 - val_iou: 0.6686
#
# Epoch 00035: val_dice_coef did not improve from 0.64214
# Epoch 36/50
# 78/78 [==============================] - 50s 647ms/step - loss: 0.0850 - dice_coef: 0.7046 - iou: 0.7311 - val_loss: 0.1586 - val_dice_coef: 0.5838 - val_iou: 0.6521
#
# Epoch 00036: val_dice_coef did not improve from 0.64214
# Epoch 37/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0811 - dice_coef: 0.7248 - iou: 0.7410 - val_loss: 0.2181 - val_dice_coef: 0.5706 - val_iou: 0.6060
#
# Epoch 00037: val_dice_coef did not improve from 0.64214
# Epoch 38/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.0811 - dice_coef: 0.7003 - iou: 0.7356 - val_loss: 0.1620 - val_dice_coef: 0.6005 - val_iou: 0.6554
#
# Epoch 00038: val_dice_coef did not improve from 0.64214
# Epoch 39/50
# 78/78 [==============================] - 50s 642ms/step - loss: 0.0786 - dice_coef: 0.7159 - iou: 0.7430 - val_loss: 0.1603 - val_dice_coef: 0.6513 - val_iou: 0.6654
#
# Epoch 00039: val_dice_coef improved from 0.64214 to 0.65134, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 40/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.0789 - dice_coef: 0.7364 - iou: 0.7422 - val_loss: 0.1514 - val_dice_coef: 0.5962 - val_iou: 0.6591
#
# Epoch 00040: val_dice_coef did not improve from 0.65134
# Epoch 41/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.0783 - dice_coef: 0.7207 - iou: 0.7405 - val_loss: 0.1444 - val_dice_coef: 0.6556 - val_iou: 0.6784
#
# Epoch 00041: val_dice_coef improved from 0.65134 to 0.65560, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 42/50
# 78/78 [==============================] - 50s 640ms/step - loss: 0.0785 - dice_coef: 0.7378 - iou: 0.7452 - val_loss: 0.2045 - val_dice_coef: 0.5268 - val_iou: 0.5930
#
# Epoch 00042: val_dice_coef did not improve from 0.65560
# Epoch 43/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0772 - dice_coef: 0.7142 - iou: 0.7424 - val_loss: 0.1660 - val_dice_coef: 0.6270 - val_iou: 0.6582
#
# Epoch 00043: val_dice_coef did not improve from 0.65560
# Epoch 44/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.0783 - dice_coef: 0.7222 - iou: 0.7385 - val_loss: 0.1620 - val_dice_coef: 0.6359 - val_iou: 0.6650
#
# Epoch 00044: val_dice_coef did not improve from 0.65560
# Epoch 45/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0736 - dice_coef: 0.7377 - iou: 0.7506 - val_loss: 0.1762 - val_dice_coef: 0.5833 - val_iou: 0.6370
#
# Epoch 00045: val_dice_coef did not improve from 0.65560
# Epoch 46/50
# 78/78 [==============================] - 50s 647ms/step - loss: 0.0731 - dice_coef: 0.7583 - iou: 0.7522 - val_loss: 0.1748 - val_dice_coef: 0.5712 - val_iou: 0.6344
#
# Epoch 00046: val_dice_coef did not improve from 0.65560
# Epoch 47/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.0711 - dice_coef: 0.7607 - iou: 0.7493 - val_loss: 0.1696 - val_dice_coef: 0.6075 - val_iou: 0.6533
#
# Epoch 00047: val_dice_coef did not improve from 0.65560
# Epoch 48/50
# 78/78 [==============================] - 50s 647ms/step - loss: 0.0712 - dice_coef: 0.7511 - iou: 0.7533 - val_loss: 0.1528 - val_dice_coef: 0.6356 - val_iou: 0.6691
#
# Epoch 00048: val_dice_coef did not improve from 0.65560
# Epoch 49/50
# 78/78 [==============================] - 50s 640ms/step - loss: 0.0693 - dice_coef: 0.7564 - iou: 0.7521 - val_loss: 0.1459 - val_dice_coef: 0.6524 - val_iou: 0.6703
#
# Epoch 00049: val_dice_coef did not improve from 0.65560
# Epoch 50/50
# 78/78 [==============================] - 50s 641ms/step - loss: 0.0688 - dice_coef: 0.7584 - iou: 0.7553 - val_loss: 0.1545 - val_dice_coef: 0.5997 - val_iou: 0.6624
#
# Epoch 00050: val_dice_coef did not improve from 0.65560

# %%
history = model.fit(Xct_train, yinfect_train, epochs=EPOCHS,
                    validation_data = (Xct_valid, yinfect_valid),
                    callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 78/78 [==============================] - 50s 644ms/step - loss: 0.0703 - dice_coef: 0.7603 - iou: 0.7542 - val_loss: 0.1630 - val_dice_coef: 0.5835 - val_iou: 0.6473
#
# Epoch 00001: val_dice_coef did not improve from 0.65560
# Epoch 2/50
# 78/78 [==============================] - 49s 633ms/step - loss: 0.0684 - dice_coef: 0.7633 - iou: 0.7575 - val_loss: 0.1530 - val_dice_coef: 0.6348 - val_iou: 0.6703
#
# Epoch 00002: val_dice_coef did not improve from 0.65560
# Epoch 3/50
# 78/78 [==============================] - 50s 642ms/step - loss: 0.0670 - dice_coef: 0.7658 - iou: 0.7585 - val_loss: 0.1491 - val_dice_coef: 0.6588 - val_iou: 0.6757
#
# Epoch 00003: val_dice_coef improved from 0.65560 to 0.65875, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 4/50
# 78/78 [==============================] - 50s 638ms/step - loss: 0.0671 - dice_coef: 0.7653 - iou: 0.7593 - val_loss: 0.1536 - val_dice_coef: 0.6487 - val_iou: 0.6703
#
# Epoch 00004: val_dice_coef did not improve from 0.65875
# Epoch 5/50
# 78/78 [==============================] - 50s 641ms/step - loss: 0.0660 - dice_coef: 0.7818 - iou: 0.7618 - val_loss: 0.1526 - val_dice_coef: 0.6668 - val_iou: 0.6792
#
# Epoch 00005: val_dice_coef improved from 0.65875 to 0.66680, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 6/50
# 78/78 [==============================] - 50s 638ms/step - loss: 0.0656 - dice_coef: 0.7736 - iou: 0.7613 - val_loss: 0.1655 - val_dice_coef: 0.6231 - val_iou: 0.6602
#
# Epoch 00006: val_dice_coef did not improve from 0.66680
# Epoch 7/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0647 - dice_coef: 0.7814 - iou: 0.7624 - val_loss: 0.1506 - val_dice_coef: 0.6759 - val_iou: 0.6794
#
# Epoch 00007: val_dice_coef improved from 0.66680 to 0.67591, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 8/50
# 78/78 [==============================] - 50s 642ms/step - loss: 0.0653 - dice_coef: 0.7802 - iou: 0.7607 - val_loss: 0.1554 - val_dice_coef: 0.6474 - val_iou: 0.6762
#
# Epoch 00008: val_dice_coef did not improve from 0.67591
# Epoch 9/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.0650 - dice_coef: 0.7682 - iou: 0.7620 - val_loss: 0.1514 - val_dice_coef: 0.6841 - val_iou: 0.6778
#
# Epoch 00009: val_dice_coef improved from 0.67591 to 0.68413, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 10/50
# 78/78 [==============================] - 50s 640ms/step - loss: 0.0633 - dice_coef: 0.7859 - iou: 0.7650 - val_loss: 0.1707 - val_dice_coef: 0.6108 - val_iou: 0.6624
#
# Epoch 00010: val_dice_coef did not improve from 0.68413
# Epoch 11/50
# 78/78 [==============================] - 50s 642ms/step - loss: 0.0634 - dice_coef: 0.7882 - iou: 0.7639 - val_loss: 0.1618 - val_dice_coef: 0.6110 - val_iou: 0.6623
#
# Epoch 00011: val_dice_coef did not improve from 0.68413
# Epoch 12/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0620 - dice_coef: 0.7919 - iou: 0.7662 - val_loss: 0.1510 - val_dice_coef: 0.6925 - val_iou: 0.6798
#
# Epoch 00012: val_dice_coef improved from 0.68413 to 0.69252, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 13/50
# 78/78 [==============================] - 50s 639ms/step - loss: 0.0609 - dice_coef: 0.7943 - iou: 0.7687 - val_loss: 0.1582 - val_dice_coef: 0.6311 - val_iou: 0.6673
#
# Epoch 00013: val_dice_coef did not improve from 0.69252
# Epoch 14/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.0618 - dice_coef: 0.7792 - iou: 0.7668 - val_loss: 0.1516 - val_dice_coef: 0.7140 - val_iou: 0.6833
#
# Epoch 00014: val_dice_coef improved from 0.69252 to 0.71404, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 15/50
# 78/78 [==============================] - 50s 636ms/step - loss: 0.0607 - dice_coef: 0.7901 - iou: 0.7699 - val_loss: 0.1606 - val_dice_coef: 0.6324 - val_iou: 0.6705
#
# Epoch 00015: val_dice_coef did not improve from 0.71404
# Epoch 16/50
# 78/78 [==============================] - 50s 641ms/step - loss: 0.0606 - dice_coef: 0.7989 - iou: 0.7699 - val_loss: 0.1569 - val_dice_coef: 0.6408 - val_iou: 0.6721
#
# Epoch 00016: val_dice_coef did not improve from 0.71404
# Epoch 17/50
# 78/78 [==============================] - 50s 647ms/step - loss: 0.0599 - dice_coef: 0.7943 - iou: 0.7701 - val_loss: 0.1609 - val_dice_coef: 0.6843 - val_iou: 0.6776
#
# Epoch 00017: val_dice_coef did not improve from 0.71404
# Epoch 18/50
# 78/78 [==============================] - 50s 638ms/step - loss: 0.0602 - dice_coef: 0.7987 - iou: 0.7693 - val_loss: 0.1673 - val_dice_coef: 0.6092 - val_iou: 0.6595
#
# Epoch 00018: val_dice_coef did not improve from 0.71404
# Epoch 19/50
# 78/78 [==============================] - 50s 638ms/step - loss: 0.0607 - dice_coef: 0.7938 - iou: 0.7693 - val_loss: 0.1544 - val_dice_coef: 0.6516 - val_iou: 0.6682
#
# Epoch 00019: val_dice_coef did not improve from 0.71404
# Epoch 20/50
# 78/78 [==============================] - 50s 640ms/step - loss: 0.0604 - dice_coef: 0.7927 - iou: 0.7700 - val_loss: 0.1559 - val_dice_coef: 0.6617 - val_iou: 0.6748
#
# Epoch 00020: val_dice_coef did not improve from 0.71404
# Epoch 21/50
# 78/78 [==============================] - 50s 644ms/step - loss: 0.0586 - dice_coef: 0.8039 - iou: 0.7732 - val_loss: 0.1468 - val_dice_coef: 0.6806 - val_iou: 0.6870
#
# Epoch 00021: val_dice_coef did not improve from 0.71404
# Epoch 22/50
# 78/78 [==============================] - 50s 642ms/step - loss: 0.0575 - dice_coef: 0.8091 - iou: 0.7740 - val_loss: 0.1537 - val_dice_coef: 0.6446 - val_iou: 0.6735
#
# Epoch 00022: val_dice_coef did not improve from 0.71404
# Epoch 23/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.0571 - dice_coef: 0.8100 - iou: 0.7741 - val_loss: 0.1496 - val_dice_coef: 0.6652 - val_iou: 0.6844
#
# Epoch 00023: val_dice_coef did not improve from 0.71404
# Epoch 24/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.0568 - dice_coef: 0.8148 - iou: 0.7756 - val_loss: 0.1518 - val_dice_coef: 0.6893 - val_iou: 0.6848
#
# Epoch 00024: val_dice_coef did not improve from 0.71404
# Epoch 25/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.0563 - dice_coef: 0.8128 - iou: 0.7757 - val_loss: 0.1525 - val_dice_coef: 0.6511 - val_iou: 0.6796
#
# Epoch 00025: val_dice_coef did not improve from 0.71404
# Epoch 26/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.0561 - dice_coef: 0.8202 - iou: 0.7763 - val_loss: 0.1553 - val_dice_coef: 0.6677 - val_iou: 0.6818
#
# Epoch 00026: val_dice_coef did not improve from 0.71404
# Epoch 27/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.0561 - dice_coef: 0.8204 - iou: 0.7771 - val_loss: 0.1513 - val_dice_coef: 0.6973 - val_iou: 0.6820
#
# Epoch 00027: val_dice_coef did not improve from 0.71404
# Epoch 28/50
# 78/78 [==============================] - 50s 636ms/step - loss: 0.0561 - dice_coef: 0.8217 - iou: 0.7775 - val_loss: 0.1611 - val_dice_coef: 0.6471 - val_iou: 0.6734
#
# Epoch 00028: val_dice_coef did not improve from 0.71404
# Epoch 29/50
# 78/78 [==============================] - 50s 640ms/step - loss: 0.0566 - dice_coef: 0.8108 - iou: 0.7740 - val_loss: 0.1607 - val_dice_coef: 0.6823 - val_iou: 0.6780
#
# Epoch 00029: val_dice_coef did not improve from 0.71404
# Epoch 30/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.0558 - dice_coef: 0.8203 - iou: 0.7772 - val_loss: 0.1506 - val_dice_coef: 0.6694 - val_iou: 0.6829
#
# Epoch 00030: val_dice_coef did not improve from 0.71404
# Epoch 31/50
# 78/78 [==============================] - 50s 637ms/step - loss: 0.0545 - dice_coef: 0.8299 - iou: 0.7792 - val_loss: 0.2057 - val_dice_coef: 0.5687 - val_iou: 0.6219
#
# Epoch 00031: val_dice_coef did not improve from 0.71404
# Epoch 32/50
# 78/78 [==============================] - 50s 642ms/step - loss: 0.0539 - dice_coef: 0.8324 - iou: 0.7803 - val_loss: 0.1498 - val_dice_coef: 0.6884 - val_iou: 0.6861
#
# Epoch 00032: val_dice_coef did not improve from 0.71404
# Epoch 33/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.0538 - dice_coef: 0.8317 - iou: 0.7805 - val_loss: 0.1497 - val_dice_coef: 0.7021 - val_iou: 0.6888
#
# Epoch 00033: val_dice_coef did not improve from 0.71404
# Epoch 34/50
# 78/78 [==============================] - 50s 646ms/step - loss: 0.0537 - dice_coef: 0.8320 - iou: 0.7812 - val_loss: 0.1507 - val_dice_coef: 0.7126 - val_iou: 0.6903
#
# Epoch 00034: val_dice_coef did not improve from 0.71404
# Epoch 35/50
# 78/78 [==============================] - 51s 650ms/step - loss: 0.0536 - dice_coef: 0.8310 - iou: 0.7816 - val_loss: 0.1584 - val_dice_coef: 0.7005 - val_iou: 0.6867
#
# Epoch 00035: val_dice_coef did not improve from 0.71404
# Epoch 36/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.0539 - dice_coef: 0.8318 - iou: 0.7811 - val_loss: 0.1595 - val_dice_coef: 0.6778 - val_iou: 0.6792
#
# Epoch 00036: val_dice_coef did not improve from 0.71404
# Epoch 37/50
# 78/78 [==============================] - 51s 648ms/step - loss: 0.0540 - dice_coef: 0.8252 - iou: 0.7789 - val_loss: 0.1885 - val_dice_coef: 0.5833 - val_iou: 0.6367
#
# Epoch 00037: val_dice_coef did not improve from 0.71404
# Epoch 38/50
# 78/78 [==============================] - 50s 638ms/step - loss: 0.0539 - dice_coef: 0.8215 - iou: 0.7799 - val_loss: 0.1569 - val_dice_coef: 0.6696 - val_iou: 0.6810
#
# Epoch 00038: val_dice_coef did not improve from 0.71404
# Epoch 39/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0527 - dice_coef: 0.8308 - iou: 0.7823 - val_loss: 0.1555 - val_dice_coef: 0.6379 - val_iou: 0.6760
#
# Epoch 00039: val_dice_coef did not improve from 0.71404
# Epoch 40/50
# 78/78 [==============================] - 50s 648ms/step - loss: 0.0528 - dice_coef: 0.8296 - iou: 0.7823 - val_loss: 0.1546 - val_dice_coef: 0.6722 - val_iou: 0.6801
#
# Epoch 00040: val_dice_coef did not improve from 0.71404
# Epoch 41/50
# 78/78 [==============================] - 51s 649ms/step - loss: 0.0520 - dice_coef: 0.8377 - iou: 0.7843 - val_loss: 0.1490 - val_dice_coef: 0.7294 - val_iou: 0.6937
#
# Epoch 00041: val_dice_coef improved from 0.71404 to 0.72937, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 42/50
# 78/78 [==============================] - 51s 648ms/step - loss: 0.0515 - dice_coef: 0.8362 - iou: 0.7852 - val_loss: 0.1515 - val_dice_coef: 0.6915 - val_iou: 0.6878
#
# Epoch 00042: val_dice_coef did not improve from 0.72937
# Epoch 43/50
# 78/78 [==============================] - 51s 649ms/step - loss: 0.0510 - dice_coef: 0.8400 - iou: 0.7849 - val_loss: 0.1572 - val_dice_coef: 0.7275 - val_iou: 0.6941
#
# Epoch 00043: val_dice_coef did not improve from 0.72937
# Epoch 44/50
# 78/78 [==============================] - 51s 650ms/step - loss: 0.0521 - dice_coef: 0.8342 - iou: 0.7839 - val_loss: 0.1585 - val_dice_coef: 0.7103 - val_iou: 0.6800
#
# Epoch 00044: val_dice_coef did not improve from 0.72937
# Epoch 45/50
# 78/78 [==============================] - 50s 641ms/step - loss: 0.0517 - dice_coef: 0.8367 - iou: 0.7844 - val_loss: 0.1555 - val_dice_coef: 0.7589 - val_iou: 0.6919
#
# Epoch 00045: val_dice_coef improved from 0.72937 to 0.75888, saving model to model_weights.augmenteddicesurface.hdf5
# Epoch 46/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0519 - dice_coef: 0.8360 - iou: 0.7840 - val_loss: 0.1601 - val_dice_coef: 0.7369 - val_iou: 0.6857
#
# Epoch 00046: val_dice_coef did not improve from 0.75888
# Epoch 47/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0976 - dice_coef: 0.7726 - iou: 0.7337 - val_loss: 1.2707 - val_dice_coef: 0.0870 - val_iou: 0.0734
#
# Epoch 00047: val_dice_coef did not improve from 0.75888
# Epoch 48/50
# 78/78 [==============================] - 50s 643ms/step - loss: 0.1787 - dice_coef: 0.5264 - iou: 0.5962 - val_loss: 0.3016 - val_dice_coef: 0.4820 - val_iou: 0.5183
#
# Epoch 00048: val_dice_coef did not improve from 0.75888
# Epoch 49/50
# 78/78 [==============================] - 50s 641ms/step - loss: 0.0935 - dice_coef: 0.6364 - iou: 0.7150 - val_loss: 0.1531 - val_dice_coef: 0.5751 - val_iou: 0.6571
#
# Epoch 00049: val_dice_coef did not improve from 0.75888
# Epoch 50/50
# 78/78 [==============================] - 50s 645ms/step - loss: 0.0689 - dice_coef: 0.6956 - iou: 0.7554 - val_loss: 0.1613 - val_dice_coef: 0.6587 - val_iou: 0.6691
#
# Epoch 00050: val_dice_coef did not improve from 0.75888

# %% [markdown]
# # **Evaluation**

# %%
weight_path = "/content/input/model_weights.augmenteddicesurface.hdf5"

# %%
model.load_weights(weight_path)
model.save('model_dice_surface_aug.h5')

# %%
# %cp "/content/input/model_dice_surface_aug.h5" "/content/drive/MyDrive/Colab Notebooks/Covid-19 U-Net/just dice 512*512/"
# %cp "/content/input/model_weights.augmenteddicesurface.hdf5" "/content/drive/MyDrive/Colab Notebooks/Covid-19 U-Net/just dice 512*512/"

# %%
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('dice vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('dice')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# **Test set evaluation**

# %%
len(Xct_test)
# Out:
# 311

# %%
predicted_test = model.predict(Xct_test)

# %%
threshold = 0.7

# use threshold to get hard predictions
predicted_test[predicted_test > threshold] = 1.0
predicted_test[predicted_test <= threshold] = 0.0

# %%
fig = plt.figure(figsize = (18,15))

image_id_test = 70
plt.subplot(1,3,1)
plt.imshow(Xct_test[image_id_test][...,0], cmap = 'bone')
plt.title('original lung')

plt.subplot(1,3,2)
plt.imshow(Xct_test[image_id_test][...,0], cmap = 'bone')
plt.imshow(yinfect_test[image_id_test][...,0],alpha = 0.5, cmap = "nipy_spectral")
plt.title('original infection mask')

plt.subplot(1,3,3)
plt.imshow(Xct_test[image_id_test][...,0], cmap = 'bone')
plt.imshow(predicted_test[image_id_test][...,0],alpha = 0.5,cmap = "nipy_spectral")
plt.title('predicted infection mask')
# Out:
# Text(0.5, 1.0, 'predicted infection mask')

# %% [markdown]
# **train set evaluation**

# %%
len(Xct_train)
# Out:
# 2480

# %%
predicted_train = model.predict(Xct_train)

# %%
threshold = 0.7

# use threshold to get hard predictions
predicted_train[predicted_train > threshold] = 1.0
predicted_train[predicted_train <= threshold] = 0.0

# %%
fig = plt.figure(figsize = (18,15))

image_id_test = 600
plt.subplot(1,3,1)
plt.imshow(Xct_train[image_id_test][...,0], cmap = 'bone')
plt.title('original lung')

plt.subplot(1,3,2)
plt.imshow(Xct_train[image_id_test][...,0], cmap = 'bone')
plt.imshow(yinfect_train[image_id_test][...,0],alpha = 0.5, cmap = "nipy_spectral")
plt.title('original infection mask')

plt.subplot(1,3,3)
plt.imshow(Xct_train[image_id_test][...,0], cmap = 'bone')
plt.imshow(predicted_train[image_id_test][...,0],alpha = 0.5,cmap = "nipy_spectral")
plt.title('predicted infection mask')
# Out:
# Text(0.5, 1.0, 'predicted infection mask')

# %% [markdown]
# **Validation set evaluation**

# %%
len(Xct_valid)
# Out:
# 310

# %%
predicted_val = model.predict(Xct_valid)

# %%
threshold = 0.7

# use threshold to get hard predictions
predicted_val[predicted_val > threshold] = 1.0
predicted_val[predicted_val <= threshold] = 0.0

# %%
fig = plt.figure(figsize = (18,15))

image_id_test = 70
plt.subplot(1,3,1)
plt.imshow(Xct_valid[image_id_test][...,0], cmap = 'bone')
plt.title('original lung')

plt.subplot(1,3,2)
plt.imshow(Xct_valid[image_id_test][...,0], cmap = 'bone')
plt.imshow(yinfect_valid[image_id_test][...,0],alpha = 0.5, cmap = "nipy_spectral")
plt.title('original infection mask')

plt.subplot(1,3,3)
plt.imshow(Xct_valid[image_id_test][...,0], cmap = 'bone')
plt.imshow(predicted_val[image_id_test][...,0],alpha = 0.5,cmap = "nipy_spectral")
plt.title('predicted infection mask')
# Out:
# Text(0.5, 1.0, 'predicted infection mask')

# %% [markdown]
# **AUC and sensitivity and specificity**

# %%
def compute_class_sens_spec(pred, label):

    class_pred = pred
    class_label = label
    
    # true positives
    tp = np.sum((class_pred==1) & (class_label==1))

    # true negatives
    tn = np.sum((class_pred==0) & (class_label==0))
    
    #false positives
    fp = np.sum((class_pred==1) & (class_label==0))
    
    # false negatives
    fn = np.sum((class_pred==0) & (class_label==1))

    # compute sensitivity and specificity
    sensitivity = tp/(tp + fn)
    specificity = tn/(tn + fp)
    AUC = 1 - ((fp/(fp+tn) + (fn/(fn+tp))))

    return sensitivity, specificity, AUC

# %%
sens_train, spec_train, AUC_train = compute_class_sens_spec(predicted_train, yinfect_train)
sens_val, spec_val, AUC_val = compute_class_sens_spec(predicted_val, yinfect_valid)
sens_test, spec_test, AUC_test = compute_class_sens_spec(predicted_test, yinfect_test)

# %%
patch_metrics = pd.DataFrame(
        columns = ['trainset', 'validationset', 'testset'],
        index = ['Sensitivity','Specificity', 'AUC'])

patch_metrics.loc['Sensitivity', 'trainset'] = sens_train
patch_metrics.loc['Specificity', 'trainset'] = spec_train
patch_metrics.loc['AUC', 'trainset'] = AUC_train

patch_metrics.loc['Sensitivity', 'validationset'] = sens_test
patch_metrics.loc['Specificity', 'validationset'] = spec_test
patch_metrics.loc['AUC', 'validationset'] = AUC_val

patch_metrics.loc['Sensitivity', 'testset'] = sens_test
patch_metrics.loc['Specificity', 'testset'] = spec_test
patch_metrics.loc['AUC', 'testset'] = AUC_test
print(patch_metrics)
# Out:
#              trainset validationset   testset
# Sensitivity  0.994627      0.934817  0.934817
# Specificity  0.999998      0.998934  0.998934
# AUC          0.994625      0.944052  0.933751
